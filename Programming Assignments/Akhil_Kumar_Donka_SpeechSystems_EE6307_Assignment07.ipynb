# %% [markdown]
# <center> <h1> <b> Speech Systems (EE6307) </b> </h1> </center>
#
#
# <dt> <h4>
#  <b> Programming Assignment - 07 - End to End Automatic Speech Recognition </b>
#
# Welcome to the seventh programming assignment in the speech systems (EE6307) course. In this programming assignment, we expect you to code an algorithm to recognize the text information in speech signal i,e, Automatic Speech Recognition (ASR). This programming assignment focus on an End-to-End ASR system that takes inputs as speech signal and textual information in it and trains the model without any explicit alignments. Connectionist Temporal Classification (CTC) loss is used to train the ASR system, and Character Error Rate (CER), and Word Error Rate (WER) are used to quantify the performance of the ASR system. We request you train the model using the "train" partition of the TIDIGITS database and evaluate the performance on the "test" partition.
#
#
# </h4> </dt>
#
#
#
#
# <b> Instructions </b>
# 1. Plagiarism is strictly prohibited.
# 2. Delayed submissions will be penalized with a scaling factor of 0.5 per day.
# 3. Please DO NOT use any machine learning libraries unless and otherwise specified.

# %% [markdown]
# <h4> <b> End to End Automatic Speech Recognition : </b>  In this part of the assignment, you need to code an algorithm to recognize the text information in speech signal.   </h4>
#
#
# [link to TIDIGITS website](https://catalog.ldc.upenn.edu/LDC93S10)
#
# [link to TIDIGITS dataset](https://drive.google.com/file/d/1E_rcPI6RfyfyKgy-MTT7WN5Nd3VWNj7T/view?usp=sharing)
#
# <dt> <h4> 1. Dataset </h4> </dt>
# <dd> <h4>  - TIDIGITS corpus contains speech originally designed and collected at Texas Instruments, Inc. (TI) to design and evaluate algorithms for speaker-independent recognition of connected digit sequences. The database includes 326 speakers (111 men, 114 women, 50 boys, and 51 girls), each pronouncing 77 digit sequences. Each speaker group is partitioned into test and training subsets. </h4> </dd>
#
# <dd> <h4> - The ASR system in this assignment needs to be trained using the "train" partition of the TIDIGITS database. Please go through the above link for finer details of the dataset. We also provided the "readme.doc" file in the shared folder. Please go through it to understand the data organization required for preparing the labels, i.e., text information.   </h4> </dd>
# <dd> <h4> - Testing data : We request you to evaluate the performance of ASR system on "test" partition of the TIDIGITS database.  </h4> </dd>
#
# <dt> <h4> 2. Data preprocessing </h4> </dt>
# <dd> <h4> - Convert the target information ( sequence of digits being spoken / sentence information ) in textual domain to sequence of numbers, where the number indicates the character position in our predefined character set.    </h4> </dd>
# <dd> <h4> - Extract log-mel filter bank energies from the speech signal    </h4> </dd>
#
#
# <dt> <h4> 3. Automatic Speech Recognition (ASR) - Architecture </h4> </dt>
#
# <img src ="https://raw.githubusercontent.com/SpeechPublications/SpeechSystems/main/model.png" >
# <center> Black Diagram of Automatic Speech Recognition Model </center>
#
# <dd> <h4> - Create the approapriate architecture ( number of layers, number of filters and hidden dimensions etc ) following the black diagram
#
# <dt> <h4> 4. Training ASR system </h4> </dt>
# <dd> <h4> -  Issue : The input ( speech signal ) and outputs ( text ) are not time aligned. Aligning the data using Hidden Markov Model (HMM) may not be a suitable option.   </h4> </dd>
# <dd> <h4> -  The ASR system is trained using the Connectionist Temporal Classificaiton (CTC) loss  </h4> </dd>
#
#
# <dt> <h4> 5. Evaluation Metrics </h4> </dt>
# <dd> <h4> - Typically the performance of ASR system is quantified in terms of Word Error Rate (WER) or Character Error Rate (CER). The codes to compute the WER and CER will be provided to you, use them to evaluate the performance   </h4> </dd>
# <dd> <h4> -  CER : Percentage of characters that were incorrectly predicted  by the ASR system      </h4> </dd>
#
#
# <dt> <h4> 6. Evaluate the performance of ASR system </h4> </dt>
# <dd> <h4> -  Use the trained ASR system and predict the characters and words using the basic GreedyDecoder and evaluate the performance in terms of CER and WER  </h4> </dd>

# %%
###############################################################################
#Mount the drive
###############################################################################
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
###############################################################################
#Download and unzip the dataset
###############################################################################
# !ls "/content/drive/MyDrive/TIDIGITS.zip"
# !cp -r "/content/drive/MyDrive/TIDIGITS.zip" .
# !unzip "TIDIGITS.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: TIDIGITS/tidigits/test/woman/pl/5883228a.wav
#   inflating: TIDIGITS/tidigits/test/woman/pl/8512455a.wav
#   inflating: TIDIGITS/tidigits/test/woman/pl/5z41736a.wav
#   inflating: TIDIGITS/tidigits/test/woman/pl/8134a.wav
#   inflating: TIDIGITS/tidigits/test/woman/pl/z65a.wav
#   inflating: TIDIGITS/tidigits/test/woman/pl/ooo766oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/pl/62o1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/pl/5a.wav
#    creating: TIDIGITS/tidigits/test/woman/bj/
#   inflating: TIDIGITS/tidigits/test/woman/bj/4b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/923a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/86194a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/9357a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/64881a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/3za.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/42a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/zza.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/3b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/5495a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/z443659a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/ob.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/6b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/6446a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/2z51a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/5z9z7a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/2b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/8b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/4z7162za.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/za.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/7z46989a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/1b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/668a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/4718a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/3ooo1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/67a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/o833132a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/726a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/135a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/39a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/3a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/ooa.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/229a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/zb.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/z343112a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/9b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/o959a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/52a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/87o1215a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/1o9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/378o726a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/o247a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/376oo28a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/218za.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/9o5a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/6z38za.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/196a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/z991a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/7b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/82a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/7a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/7768736a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/o65a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/45o4oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/15o3456a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/78674a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/533a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/84991z2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/14248a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/55a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/5b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/2o6o7a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/9za.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/97za.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/z1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/25z57a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/7o4oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/5a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/85398a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bj/41z8a.wav
#    creating: TIDIGITS/tidigits/test/woman/gb/
#   inflating: TIDIGITS/tidigits/test/woman/gb/4b.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/5234a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/29a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/552za.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/7z63a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/2oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/z5z23a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/3b.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/2z8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/314a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/ob.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/6b.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/811a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/7o736a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/o14a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/5484za.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/2b.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/8b.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/5zb.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/115a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/41a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/45829a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/9164o97a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/17533a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/za.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/1b.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/85oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/8o2289oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/9976659a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/2258a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/193626za.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/4672a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/3zza.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/95a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/649o4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/9661579a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/o3o6513a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/3a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/5za.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/zb.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/347a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/9b.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/63a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/69za.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/96ooa.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/z4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/31a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/o81o9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/4469a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/7b.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/o161oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/7a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/z9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/1o8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/4355389a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/6za.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/z18a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/683o387a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/7z284a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/5b.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/z3z568za.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/32o77o4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/1921a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/79886a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/o548a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/85125a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/2427a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/7172a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/5a.wav
#   inflating: TIDIGITS/tidigits/test/woman/gb/8z86712a.wav
#    creating: TIDIGITS/tidigits/test/woman/dp/
#   inflating: TIDIGITS/tidigits/test/woman/dp/4b.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/59za.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/275a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/614a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/33a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/68z366za.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/53a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/179o9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/o1957ooa.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/3b.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/8629a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/2694197a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/447a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/ob.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/1624za.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/6b.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/37152a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/7131a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/73a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/2b.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/9oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/8b.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/846a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/115a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/za.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/11a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/1b.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/z921a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/8756a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/342a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/zz777a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/o5485a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/8o4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/o6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/4z438a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/z3a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/z442z94a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/9618237a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/5oo31o6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/3a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/zb.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/4oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/9b.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/z839293a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/7816oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/1z665a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/o93oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/9732a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/5z25a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/7641o89a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/9913a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/7b.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/98a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/7a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/3885695a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/65z8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/546ooa.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/499a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/8zzz1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/689a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/5b.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/798a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/21a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/22a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/63676a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/23z5a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/o357451a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/5a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/35o2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/dp/4964oo8a.wav
#    creating: TIDIGITS/tidigits/test/woman/ml/
#   inflating: TIDIGITS/tidigits/test/woman/ml/4b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/o42a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/6854a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/1o78a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/z751a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/65a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/2oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/7646374a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/3b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/9143o31a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/ob.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/2z32za.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/3z97a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/6b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/6z275a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/oo88oo6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/73a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/99oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/2b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/8b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/zz6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/327o9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/za.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/o11a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/1b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/24o2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/5267983a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/o88oo9oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/5o5536oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/35a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/228a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/3a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/829ooa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/1625a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/843a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/94o3o45a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/zb.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/9b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/1566z35a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/69621a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/o17a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/28934a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/72oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/4z448a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/469a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/7z1z558a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/5z81a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/16a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/7b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/86647a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/83a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/7a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/z9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/92a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/47741a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/38a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/41963a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/5b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/372a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/67z6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/57844a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/8773a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/49a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/z1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/1133187a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/995a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/z719a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/76o548oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/5345a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ml/5a.wav
#    creating: TIDIGITS/tidigits/test/woman/ak/
#   inflating: TIDIGITS/tidigits/test/woman/ak/4b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/75a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/3b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/89a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/9196951a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/ob.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/6b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/44z5938a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/624a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/3615a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/86z1162a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/2b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/z176zz2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/7958a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/99731a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/9oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/1o46a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/8b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/84z3z51a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/157a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/za.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/1b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/9858a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/711a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/276317oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/25a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/1za.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/o9oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/35a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/3a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/o69a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/ooa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/o67o3a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/zb.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/z6za.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/9b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/2za.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/63a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/5z874a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/6728za.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/z4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/532a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/45681a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/oo21641a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/4978a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/521z9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/4688a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/55619a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/642a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/7b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/1393387a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/84983a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/55oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/z7z2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/7a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/942oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/334a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/77278a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/1237743a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/3z3z9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/5b.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/85a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/zz7z4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/3z82a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/714oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/235oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/48z66zza.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/289a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/6654599a.wav
#   inflating: TIDIGITS/tidigits/test/woman/ak/5a.wav
#    creating: TIDIGITS/tidigits/test/woman/kb/
#   inflating: TIDIGITS/tidigits/test/woman/kb/4b.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/471oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/275a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/62a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/9946a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/165a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/3za.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/z5za.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/313535za.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/3b.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/zz3a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/58o4oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/91a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/z23z1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/ob.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/6b.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/o33a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/2b.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/oo7a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/2643463a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/6672a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/8b.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/889o976a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/8z9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/4528a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/za.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/o78a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/z8583a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/1b.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/8519za.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/137781za.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/4z22445a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/25734z8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/33816z7a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/53968z4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/98oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/3a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/7529a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/1oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/97a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/54a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/zb.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/82zz4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/2z992a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/9b.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/7z51a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/98614a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/7o3a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/5z39a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/4892a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/76a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/61zz6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/7b.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/65577o6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/7a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/zz19a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/o871479a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/67937a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/25955a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/38a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/18a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/5b.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/3o12a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/56a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/729a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/886za.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/17321a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/o2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/4324842a.wav
#   inflating: TIDIGITS/tidigits/test/woman/kb/5a.wav
#    creating: TIDIGITS/tidigits/test/woman/bw/
#   inflating: TIDIGITS/tidigits/test/woman/bw/4b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/62a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/812o859a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/53a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/77z9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/684a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/42a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/3b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/z5a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/52472a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/13a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/ob.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/7o74oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/6b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/66z3a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/oo468a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/39zza.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/2b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/1119673a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/z757a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/8b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/2261a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/7z1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/41a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/za.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/6o6o2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/217a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/1b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/5639826a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/zz1zz8za.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/9179a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/4518a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/oo581a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/o85o348a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/3a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/zb.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/35536a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/712a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/z25a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/9b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/34a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/1z278a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/o1oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/29oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/2z846a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/76a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/zz4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/oo23a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/935o324a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/7b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/98a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/7a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/892a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/163o993a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/9z72386a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/55a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/5b.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/337a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/87o6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/58942o7a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/4325a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/96a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/865a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/31436a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/45644a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/28z5a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/659954oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/878ooa.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/5a.wav
#   inflating: TIDIGITS/tidigits/test/woman/bw/1528833a.wav
#    creating: TIDIGITS/tidigits/test/woman/mc/
#   inflating: TIDIGITS/tidigits/test/woman/mc/4b.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/65a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/3za.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/z1319a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/6o762a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/o877a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/12oo8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/3b.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/48z5415a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/ob.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/6b.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/665a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/233o37oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/9914113a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/25915a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/296a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/2b.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/o4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/8b.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/1a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/8oo9oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/za.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/1b.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/1z8a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/zz3zzz9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/7z98a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/3245a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/o6a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/6z61z57a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/57a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/4672a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/43185a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/39a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/3a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/56923a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/816oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/8796446a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/5za.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/zb.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/712a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/17a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/9b.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/o5942a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/355a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/75o3294a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/z682a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/45a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/7b.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/93528a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/7a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/9o698a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/343a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/736a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/z254a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/2z4za.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/524a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/7678a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/z7844z4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/47z21a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/9726881a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/849a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/9a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/4a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/6219956a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/5b.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/93a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/89oa.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/174z336a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/1863a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/o2a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/5a.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/266za.wav
#   inflating: TIDIGITS/tidigits/test/woman/mc/51oa.wav
#    creating: TIDIGITS/tidigits/test/man/
#    creating: TIDIGITS/tidigits/test/man/gw/
#   inflating: TIDIGITS/tidigits/test/man/gw/4b.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/8a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/2887897a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/81z66a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/oa.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/2oa.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/7758o54a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/7418261a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/o6o21a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/42a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/zza.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/3b.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/o33o2o5a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/z9259a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/ob.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/6b.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/49628a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/9z127a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/442a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/34oo4a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/2b.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/65o9a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/6437a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/8b.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/1a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/6a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/179z838a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/7689a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/za.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/5z73a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/1b.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/143a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/324163za.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/79a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/168a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/35a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/3a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/ooa.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/546a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/zb.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/17a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/9b.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/23252a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/84a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/3z229a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/2a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/4zz7z3za.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/782a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/48z5a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/z645a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/6z4z1a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/zz4a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/9951a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/7b.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/5ooa.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/911o4o8a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/7a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/149a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/2291a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/31o3a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/556a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/9a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/4a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/5b.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/571a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/69a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/o199a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/66a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/858z3a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/812z276a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/9231518a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/8o757a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/9345356a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/zz8a.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/o19oa.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/2ob.wav
#   inflating: TIDIGITS/tidigits/test/man/gw/5a.wav
#    creating: TIDIGITS/tidigits/test/man/nl/
#   inflating: TIDIGITS/tidigits/test/man/nl/4b.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/8a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/6zz47z1a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/7551322a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/33a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/oa.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/o5a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/93za.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/19974a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/3b.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/5o2oa.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/8569477a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/ob.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/3561a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/6b.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/811a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/z441za.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/548365oa.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/zz1523za.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/2b.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/z2a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/133a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/72a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/718a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/82o6oa.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/8b.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/1a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/9z5za.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/z28z667a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/6a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/9oo6o43a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/za.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/1b.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/2318a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/z86zza.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/39zz369a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/oo38a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/1457a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/624o7o9a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/95a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/62729a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/46a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/734oa.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/3a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/o12a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/54a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/zb.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/17a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/9b.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/4z8za.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/27984a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/2a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/34a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/6492z68a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/6886a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/29oa.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/22641a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/o21a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/o79a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/8196a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/7oo3oa.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/16a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/7b.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/7a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/8o8a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/28324a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/9a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/4a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/5b.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/4425z91a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/49a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/961oa.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/553a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/3o4a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/42178a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/5384a.wav
#   inflating: TIDIGITS/tidigits/test/man/nl/5a.wav
#    creating: TIDIGITS/tidigits/test/man/ka/
#   inflating: TIDIGITS/tidigits/test/man/ka/4b.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/8a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/235o4o3a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/4z7a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/oa.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/65a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/8622a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/5815418a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/43a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/31o2a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/118a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/3b.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/ob.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/o583552a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/6b.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/2579a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/2b.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/6977a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/47a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/59461a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/8b.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/1a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/6a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/2o32a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/5282a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/z2917a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/za.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/1b.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/z279537a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/1367a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/7zzz9z6a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/o72a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/7769a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/3a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/z48z436a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/ooa.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/263a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/zb.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/51a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/27166a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/oob.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/z6z17a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/9b.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/2a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/8o1o2a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/91421a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/9o668a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/82937a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/19a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/388a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/7b.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/7a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/93421a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/884za.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/z99a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/64o9451a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/6za.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/92o1648a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/38a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/99a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/9a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/4a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/47849a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/5b.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/72544a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/739o498a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/32a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/786a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/8331a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/5z74a.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/11o87ooa.wav
#   inflating: TIDIGITS/tidigits/test/man/ka/122a.wav
# ...
#   inflating: TIDIGITS/tidigits/test/man/fs/11o92a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/24a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/8b.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/1a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/o1oo812a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/6a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/7576a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/za.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/6oa.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/59a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/1b.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/151a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/2146598a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/5z55z29a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/z6723z6a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/3a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/545a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/ooa.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/o5575a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/zb.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/1zz31a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/887za.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/477a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/9b.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/6662o71a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/335a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/2a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/649z2z3a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/868a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/394a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/27o63a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/328z9a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/79o37a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/5318o91a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/7b.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/83a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/7a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/z454a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/97444a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/6za.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/z791a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/78414a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/3837a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/734778za.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/9a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/5271848a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/4a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/5b.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/69a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/2895a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/93a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/94a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/4z82a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/421a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/961a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/8996a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/4334a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/o2a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/5a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/93252a.wav
#   inflating: TIDIGITS/tidigits/test/man/fs/oo19a.wav
#    creating: TIDIGITS/tidigits/test/man/gp/
#   inflating: TIDIGITS/tidigits/test/man/gp/4b.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/8a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/8139oo7a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/2ooa.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/oa.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/z78za.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/3b.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/z38z467a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/13a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/2z2a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/ob.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/6b.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/9243262a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/4831a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/2b.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/47a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/8648a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/6968717a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/8b.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/1a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/47982a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/6a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/oo191a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/za.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/1b.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/568z829a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/zzz9a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/79519a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/15a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/37a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/95a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/1za.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/o1a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/9454a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/3a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/24o7o6oa.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/4963a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/zb.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/9z5a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/9b.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/z94a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/2a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/765a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/74z7a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/593o4a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/z4a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/72312a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/884a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/3o526a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/7b.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/69922a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/7a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/15z8973a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/1742oa.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/759a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/325z5a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/556a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/254a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/38a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/9a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/4a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/5b.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/337a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/849za.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/2116a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/86z1za.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/66oo985a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/o8993a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/66a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/o3a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/o58a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/52814zza.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/4434427a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/5o29762a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/6187a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/5a.wav
#   inflating: TIDIGITS/tidigits/test/man/gp/912za.wav
#    creating: TIDIGITS/tidigits/test/man/hm/
#   inflating: TIDIGITS/tidigits/test/man/hm/659oa.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/4b.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/8a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/85zza.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/oa.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/65a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/3za.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/53a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/z66a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/94498a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/4z71611a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/42a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/3b.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/4ooa.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/7z5a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/ob.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/6b.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/z2zz7a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/2b.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/47a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/9683a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/8b.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/1a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/4966o97a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/7764a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/92228a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/6a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/2o27869a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/o89a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/za.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/19243a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/11a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/1b.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/63524a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/1543a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/3zza.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/z3a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/o384899a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/314oa.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/o5167ooa.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/823a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/3a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/9z4a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/1oa.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/ooa.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/279a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/8258146a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/zb.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/713453oa.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/6236a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/9b.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/268a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/37o21a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/2a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/o5129a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/385a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/8628za.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/8755931a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/z94761za.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/5oo4o32a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/7b.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/57369a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/7a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/798188oa.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/z9a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/7729a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/26a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/9a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/58oa.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/12184a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/4a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/5b.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/9557a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/25zz8a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/6o67a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/56z3a.wav
#   inflating: TIDIGITS/tidigits/test/man/hm/5a.wav
#    creating: TIDIGITS/tidigits/test/man/fr/
#   inflating: TIDIGITS/tidigits/test/man/fr/4b.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/14z8a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/8a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/617ooa.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/8579za.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/oa.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/84134a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/3za.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/11ooo74a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/43a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/zza.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/3o44o55a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/3b.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/67o5381a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/oo3a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/o9o9a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/ob.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/6b.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/464o1a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/934a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/6o6a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/2b.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/19915a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/o7a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/8b.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/1a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/379a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/6a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/o86a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/8za.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/2624a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/za.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/1b.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/9o23o63a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/31z72a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/zz198a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/45o3a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/25a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/95a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/8925z85a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/2333a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/98oa.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/3a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/zb.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/548za.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/9b.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/z58a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/216a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/63a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/2a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/426za.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/7z3z2a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/395a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/5394a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/z474183a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/884a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/o148o46a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/16a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/7b.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/7a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/z9a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/49245z6a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/77829a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/7586283a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/93282a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/9a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/4a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/5b.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/7811351a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/7527a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/596a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/52o2a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/68876a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/22a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/5a.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/172za.wav
#   inflating: TIDIGITS/tidigits/test/man/fr/5121876a.wav

# %%
#All imports
import os
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.optim as optim
import torch.nn.functional as F
import torchaudio
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
import soundfile
import numpy
import pandas as pd
from tqdm import tqdm
import time
from typing import List
import IPython
from torchaudio.models.decoder import ctc_decoder
from torchaudio.utils import download_asset
from torchaudio.models.decoder import download_pretrained_files

# %%
###############################################################################
#Pre-processing the data
###############################################################################
class TextTransform:
    """Maps characters to integers and vice versa"""
    def __init__(self):
        char_map_str = """
        ' 0
        <SPACE> 1
        e 2
        f 3
        g 4
        h 5
        i 6
        n 7
        o 8
        r 9
        s 10
        t 11
        u 12
        v 13
        w 14
        x 15
        z 16
        """
        self.char_map = {}
        self.index_map = {}
        for line in char_map_str.strip().split('\n'):
            ch, index = line.split()
            self.char_map[ch] = int(index)
            self.index_map[int(index)] = ch
        self.index_map[1] = ' '

    def text_to_int(self, text):
        """ Use a character map and convert text to an integer sequence """
        int_sequence = []
        for c in text:
            if c == ' ':
                ch = self.char_map['<SPACE>']
            else:
                ch = self.char_map[c]
            int_sequence.append(ch)
        return int_sequence

    def int_to_text(self, labels):
        """ Use a character map and convert integer labels to an text sequence """
        string = []
        for i in labels:
            string.append(self.index_map[i])

        return ''.join(string).replace('<SPACE>', ' ')

class Features(nn.Module):
    def __init__(self,sample_rate=16000,n_mels=64,n_fft=512,log_input=True):
        super(Features, self).__init__()
        self.n_mels = n_mels 
        self.log_input = log_input
        self.n_fft = n_fft
        self.sample_rate = sample_rate
        
        self.melspectrogram = torch.nn.Sequential( torchaudio.transforms.MelSpectrogram(sample_rate=16000,n_mels=64,n_fft=512) )        
       
    def forward(self,x_input):
        x_mfb = self.melspectrogram(x_input) + 1e-6
        if self.log_input: x_mfb_log = x_mfb.log()
        return x_mfb_log

train_audio_transforms = nn.Sequential(
    Features(),
    torchaudio.transforms.FrequencyMasking(freq_mask_param=15),
    torchaudio.transforms.TimeMasking(time_mask_param=50)
)

#######################
#Create object of Features class for training and testing data.
#######################

valid_audio_transforms = Features()

#######################
#Create object of TextTransform() class
#######################
text_transform = TextTransform()

def data_processing(data, data_type="train"):
    spectrograms = []
    labels = []
    input_lengths = []
    label_lengths = []
    # utts = []
    for (waveform, utterance) in data:
        if data_type == 'train':
            spec = train_audio_transforms(waveform).squeeze(0).transpose(0, 1)
        elif data_type == 'valid':
            spec = valid_audio_transforms(waveform).squeeze(0).transpose(0, 1)
        else:
            raise Exception('data_type should be train or valid')
        spectrograms.append(spec)
        label = torch.Tensor(text_transform.text_to_int(utterance.lower()))
        labels.append(label)
        input_lengths.append(spec.shape[0]//2)
        label_lengths.append(len(label))
        # utts.append(utterance)

    spectrograms = nn.utils.rnn.pad_sequence(spectrograms, batch_first=True).unsqueeze(1).transpose(2, 3)
    labels = nn.utils.rnn.pad_sequence(labels, batch_first=True)

    return spectrograms, labels, input_lengths, label_lengths

# %%
###############################################################################
#Speech Recognition Model
###############################################################################
#Create SpeechRecognitionModel following the black diagram provided.

class CNNLayerNorm(nn.Module):
    """Layer normalization built for cnns input"""
    def __init__(self, n_feats):
        super(CNNLayerNorm, self).__init__()
        self.layer_norm = nn.LayerNorm(n_feats)

    def forward(self, x):
        # x (batch, channel, feature, time)
        x = x.transpose(2, 3).contiguous() # (batch, channel, time, feature)
        x = self.layer_norm(x)
        return x.transpose(2, 3).contiguous() # (batch, channel, feature, time) 


class ResidualCNN(nn.Module):
    """Residual CNN inspired by https://arxiv.org/pdf/1603.05027.pdf
        except with layer norm instead of batch norm
    """
    def __init__(self, in_channels, out_channels, kernel, stride, dropout, n_feats):
        super(ResidualCNN, self).__init__()

        self.cnn1 = nn.Conv2d(in_channels, out_channels, kernel, stride, padding=kernel//2)
        self.cnn2 = nn.Conv2d(out_channels, out_channels, kernel, stride, padding=kernel//2)
        self.dropout1 = nn.Dropout(dropout)
        self.dropout2 = nn.Dropout(dropout)
        self.layer_norm1 = CNNLayerNorm(n_feats)
        self.layer_norm2 = CNNLayerNorm(n_feats)

    def forward(self, x):
        residual = x  # (batch, channel, feature, time)
        x = self.layer_norm1(x)
        x = F.gelu(x)
        x = self.dropout1(x)
        x = self.cnn1(x)
        x = self.layer_norm2(x)
        x = F.gelu(x)
        x = self.dropout2(x)
        x = self.cnn2(x)
        x += residual
        return x # (batch, channel, feature, time)


class BidirectionalGRU(nn.Module):

    def __init__(self, rnn_dim, hidden_size, dropout, batch_first):
        super(BidirectionalGRU, self).__init__()

        self.BiGRU = nn.GRU(
            input_size=rnn_dim, hidden_size=hidden_size,
            num_layers=1, batch_first=batch_first, bidirectional=True)
        self.layer_norm = nn.LayerNorm(rnn_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.layer_norm(x)
        x = F.gelu(x)
        x, _ = self.BiGRU(x)
        x = self.dropout(x)
        return x


class SpeechRecognitionModel(nn.Module):
    
    def __init__(self, n_cnn_layers, n_rnn_layers, rnn_dim, n_class, n_feats, stride=2, dropout=0.1):
        super(SpeechRecognitionModel, self).__init__()
        n_feats = n_feats//2
        self.cnn = nn.Conv2d(1, 32, 3, stride=stride, padding=3//2)  # cnn for extracting heirachal features

        # n residual cnn layers with filter size of 32
        self.rescnn_layers = nn.Sequential(*[
            ResidualCNN(32, 32, kernel=3, stride=1, dropout=dropout, n_feats=n_feats) 
            for _ in range(n_cnn_layers)
        ])
        self.fully_connected = nn.Linear(n_feats*32, rnn_dim)
        self.birnn_layers = nn.Sequential(*[
            BidirectionalGRU(rnn_dim=rnn_dim if i==0 else rnn_dim*2,
                             hidden_size=rnn_dim, dropout=dropout, batch_first=i==0)
            for i in range(n_rnn_layers)
        ])
        self.classifier = nn.Sequential(
            nn.Linear(rnn_dim*2, rnn_dim),  # birnn returns rnn_dim*2
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(rnn_dim, n_class)
        )

    def forward(self, x):
        x = self.cnn(x)
        x = self.rescnn_layers(x)
        sizes = x.size()
        x = x.view(sizes[0], sizes[1] * sizes[2], sizes[3])  # (batch, feature, time)
        x = x.transpose(1, 2) # (batch, time, feature)
        x = self.fully_connected(x)
        x = self.birnn_layers(x)
        x = self.classifier(x)
        return x

class IterMeter(object):
    """keeps track of total iterations"""
    def __init__(self):
        self.val = 0

    def step(self):
        self.val += 1

    def get(self):
        return self.val

# %%
###############################################################################
#Training Script
###############################################################################
def train(model, device, train_loader, criterion, optimizer, scheduler, epoch, iter_meter):
    #Set the model in training mode
    model.train()

    #Get the data length
    data_len = len(train_loader.dataset)

    #Iterate through the training dataset and train the model
    for batch_idx, _data in enumerate(train_loader):

        #Get the spectrograms (input data), labels (targets)      
        spectrograms, labels, input_lengths, label_lengths = _data 
        spectrograms, labels = spectrograms.to(device), labels.to(device)

        #Set the gradients of the parameters to zero's
        optimizer.zero_grad()

        #Obtain the predictions 
        output = model(spectrograms)  # (batch, time, n_class)
        output = F.log_softmax(output, dim=2)
        output = output.transpose(0, 1) # (time, batch, n_class)

        #Compute the loss
        loss = criterion(output, labels, input_lengths, label_lengths)

        #Backpropagate the loss to get the gradients of the parameters
        loss.backward()

        #Update the parameters
        optimizer.step()

        #Update the learning rate scheduler
        scheduler.step()
        iter_meter.step()

        #Print the training metrics at regular interval, let us say once in 100 iterations etc
        if batch_idx % 100 == 0 or batch_idx == data_len:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(spectrograms), data_len,
                100. * batch_idx / len(train_loader), loss.item()))

# %%
###############################################################################
#Evaluation Metrics
###############################################################################

def avg_wer(wer_scores, combined_ref_len):
    return float(sum(wer_scores)) / float(combined_ref_len)


def _levenshtein_distance(ref, hyp):
    """Levenshtein distance is a string metric for measuring the difference
    between two sequences. Informally, the levenshtein disctance is defined as
    the minimum number of single-character edits (substitutions, insertions or
    deletions) required to change one word into the other. We can naturally
    extend the edits to word level when calculate levenshtein disctance for
    two sentences.
    """
    m = len(ref)
    n = len(hyp)

    # special case
    if ref == hyp:
        return 0
    if m == 0:
        return n
    if n == 0:
        return m

    if m < n:
        ref, hyp = hyp, ref
        m, n = n, m

    # use O(min(m, n)) space
    distance = np.zeros((2, n + 1), dtype=np.int32)

    # initialize distance matrix
    for j in range(0,n + 1):
        distance[0][j] = j

    # calculate levenshtein distance
    for i in range(1, m + 1):
        prev_row_idx = (i - 1) % 2
        cur_row_idx = i % 2
        distance[cur_row_idx][0] = i
        for j in range(1, n + 1):
            if ref[i - 1] == hyp[j - 1]:
                distance[cur_row_idx][j] = distance[prev_row_idx][j - 1]
            else:
                s_num = distance[prev_row_idx][j - 1] + 1
                i_num = distance[cur_row_idx][j - 1] + 1
                d_num = distance[prev_row_idx][j] + 1
                distance[cur_row_idx][j] = min(s_num, i_num, d_num)

    return distance[m % 2][n]


def word_errors(reference, hypothesis, ignore_case=False, delimiter=' '):
    """Compute the levenshtein distance between reference sequence and
    hypothesis sequence in word-level.
    :param reference: The reference sentence.
    :type reference: basestring
    :param hypothesis: The hypothesis sentence.
    :type hypothesis: basestring
    :param ignore_case: Whether case-sensitive or not.
    :type ignore_case: bool
    :param delimiter: Delimiter of input sentences.
    :type delimiter: char
    :return: Levenshtein distance and word number of reference sentence.
    :rtype: list
    """
    if ignore_case == True:
        reference = reference.lower()
        hypothesis = hypothesis.lower()

    ref_words = reference.split(delimiter)
    hyp_words = hypothesis.split(delimiter)

    edit_distance = _levenshtein_distance(ref_words, hyp_words)
    return float(edit_distance), len(ref_words)


def char_errors(reference, hypothesis, ignore_case=False, remove_space=False):
    """Compute the levenshtein distance between reference sequence and
    hypothesis sequence in char-level.
    :param reference: The reference sentence.
    :type reference: basestring
    :param hypothesis: The hypothesis sentence.
    :type hypothesis: basestring
    :param ignore_case: Whether case-sensitive or not.
    :type ignore_case: bool
    :param remove_space: Whether remove internal space characters
    :type remove_space: bool
    :return: Levenshtein distance and length of reference sentence.
    :rtype: list
    """
    if ignore_case == True:
        reference = reference.lower()
        hypothesis = hypothesis.lower()

    join_char = ' '
    if remove_space == True:
        join_char = ''

    reference = join_char.join(filter(None, reference.split(' ')))
    hypothesis = join_char.join(filter(None, hypothesis.split(' ')))

    edit_distance = _levenshtein_distance(reference, hypothesis)
    return float(edit_distance), len(reference)


def wer(reference, hypothesis, ignore_case=False, delimiter=' '):
    """Calculate word error rate (WER). WER compares reference text and
    hypothesis text in word-level. WER is defined as:
    .. math::
        WER = (Sw + Dw + Iw) / Nw
    where
    .. code-block:: text
        Sw is the number of words subsituted,
        Dw is the number of words deleted,
        Iw is the number of words inserted,
        Nw is the number of words in the reference
    We can use levenshtein distance to calculate WER. Please draw an attention
    that empty items will be removed when splitting sentences by delimiter.
    :param reference: The reference sentence.
    :type reference: basestring
    :param hypothesis: The hypothesis sentence.
    :type hypothesis: basestring
    :param ignore_case: Whether case-sensitive or not.
    :type ignore_case: bool
    :param delimiter: Delimiter of input sentences.
    :type delimiter: char
    :return: Word error rate.
    :rtype: float
    :raises ValueError: If word number of reference is zero.
    """
    edit_distance, ref_len = word_errors(reference, hypothesis, ignore_case,
                                         delimiter)

    if ref_len == 0:
        raise ValueError("Reference's word number should be greater than 0.")

    wer = float(edit_distance) / ref_len
    return wer


def cer(reference, hypothesis, ignore_case=False, remove_space=False):
    """Calculate charactor error rate (CER). CER compares reference text and
    hypothesis text in char-level. CER is defined as:
    .. math::
        CER = (Sc + Dc + Ic) / Nc
    where
    .. code-block:: text
        Sc is the number of characters substituted,
        Dc is the number of characters deleted,
        Ic is the number of characters inserted
        Nc is the number of characters in the reference
    We can use levenshtein distance to calculate CER. Chinese input should be
    encoded to unicode. Please draw an attention that the leading and tailing
    space characters will be truncated and multiple consecutive space
    characters in a sentence will be replaced by one space character.
    :param reference: The reference sentence.
    :type reference: basestring
    :param hypothesis: The hypothesis sentence.
    :type hypothesis: basestring
    :param ignore_case: Whether case-sensitive or not.
    :type ignore_case: bool
    :param remove_space: Whether remove internal space characters
    :type remove_space: bool
    :return: Character error rate.
    :rtype: float
    :raises ValueError: If the reference length is zero.
    """
    edit_distance, ref_len = char_errors(reference, hypothesis, ignore_case,
                                         remove_space)

    if ref_len == 0:
        raise ValueError("Length of reference should be greater than 0.")

    cer = float(edit_distance) / ref_len
    return cer

# %%
###############################################################################
#Decoder
###############################################################################
def GreedyDecoder(output, labels, label_lengths, blank_label=17, collapse_repeated=True):
	arg_maxes = torch.argmax(output, dim=2)
	decodes = []
	targets = []
	for i, args in enumerate(arg_maxes):
		decode = []
		targets.append(text_transform.int_to_text(labels[i][:label_lengths[i]].tolist()))
		for j, index in enumerate(args):
			if index != blank_label:
				if collapse_repeated and j != 0 and index == args[j -1]:
					continue
				decode.append(index.item())
		decodes.append(text_transform.int_to_text(decode))
	return decodes, targets

# %%
###############################################################################
#Testing Script
###############################################################################
def test(model, device, test_loader, criterion, epoch, iter_meter, decoder="greedy"):
    print('\nevaluating...')
    model.eval()
    test_loss = 0
    test_cer, test_wer = [], []
    with torch.no_grad():
        for i, _data in enumerate(test_loader):
            #Load data and labels
            spectrograms, labels, input_lengths, label_lengths = _data 
            spectrograms, labels = spectrograms.to(device), labels.to(device)

            #Get the predictions
            output = model(spectrograms)  # (batch, time, n_class)
            output = F.log_softmax(output, dim=2)
            output = output.transpose(0, 1) # (time, batch, n_class)

            #Compute the test loss
            loss = criterion(output, labels, input_lengths, label_lengths)
            test_loss += loss.item() / len(test_loader)

            if decoder=="greedy":
              #Decode the text information using GreedyDecoder
              decoded_preds, decoded_targets = GreedyDecoder(output.transpose(0, 1), labels, label_lengths)
              
            #Compute CER and WER
            for j in range(len(decoded_preds)):
                test_cer.append(cer(decoded_targets[j], decoded_preds[j]))
                test_wer.append(wer(decoded_targets[j], decoded_preds[j]))

    #Compute average CER and WER
    avg_cer = sum(test_cer)/len(test_cer)
    avg_wer = sum(test_wer)/len(test_wer)

    print('Test set: Average loss: {:.4f}, Average CER: {:4f} Average WER: {:.4f}\n'.format(test_loss, avg_cer, avg_wer))

# %%
#################################################################
#Function to load the speech signal
#################################################################
def loadWAV(filename):
    signal, sr = torchaudio.load(filename)
    resampler = torchaudio.transforms.Resample(sr, 16000)
    return resampler(signal)

def textProc(textString):
    mapDict = {
            "z" : "zero",
            "o" : "oh",
            "1" : "one",
            "2" : "two",
            "3" : "three",
            "4" : "four",
            "5" : "five",
            "6" : "six",
            "7" : "seven",
            "8" : "eight",
            "9" : "nine"
    }
    label = [mapDict[x] for x in textString]
    return " ".join(label)

#################################################################
#Dataset loader to create labels from the text files
#################################################################
class TDigitsDataset(Dataset):
    def __init__(self,train_list,base_dir):

        #Create the properties of class
        self.read_files = [line.rstrip('\n') for line in open(train_list)]
        self.wavs = []
        self.labels = []

        #Read training files
        for sample in tqdm(self.read_files):
          filepath = sample.split(' ')[1]
          label = sample.split(' ')[0][3:-1]
          label = textProc(label)
          y = loadWAV(filepath)
          self.wavs.append(y)
          self.labels.append(label)
        
    def __getitem__(self, index):
        #Load wavefiles and labels and return them
        return (self.wavs[index], self.labels[index])

    def __len__(self):
        #Return the lenght of dataset
        return len(self.wavs)

# %%
BATCH_SIZE = 10
use_cuda = torch.cuda.is_available()

#Define training and testing lists
train_list = "TIDIGITS/train_list.txt"
test_list = "TIDIGITS/test_list.txt"
base_dir = "TIDIGITS/"

#Create dataset generators and loaders for training and testing data
print("Creating Training Dataset :")
train_dataset = TDigitsDataset(train_list, base_dir)

print("Creating Test Dataset :")
test_dataset = TDigitsDataset(test_list, base_dir)

#Create dataset loaders for training
kwargs = {'num_workers': 2, 'pin_memory': True} if use_cuda else {}
train_loader = data.DataLoader(dataset=train_dataset,
                                batch_size=BATCH_SIZE,
                                shuffle=True,
                                collate_fn=lambda x: data_processing(x, 'train'),
                                **kwargs)
    
#Create dataset loaders for testing
test_loader = data.DataLoader(dataset=test_dataset,
                                batch_size=BATCH_SIZE,
                                shuffle=False,
                                collate_fn=lambda x: data_processing(x, 'valid'),
                                **kwargs)
# Out:
# Creating Training Dataset :
# 100%|██████████| 8613/8613 [00:13<00:00, 646.85it/s]
# Creating Test Dataset :
# 100%|██████████| 8700/8700 [00:13<00:00, 640.95it/s]

# %%
###############################################################################
#Main script to train and evaluate the model
###############################################################################
def main(hparams, train_loader, test_loader, state=None):
   
    #Set the device
    use_cuda = torch.cuda.is_available()
    torch.manual_seed(7)
    device = torch.device("cuda" if use_cuda else "cpu")

    #Create model object
    model = SpeechRecognitionModel(
        hparams['n_cnn_layers'], hparams['n_rnn_layers'], hparams['rnn_dim'],
        hparams['n_class'], hparams['n_feats'], hparams['stride'], hparams['dropout']
        ).to(device)

    #Print model properties i.e layers, parameters etc
    print(model)
    print('Num Model Parameters', sum([param.nelement() for param in model.parameters()]))

    #Create optimizer
    optimizer = optim.AdamW(model.parameters(), hparams['learning_rate'])

    start_epoch = 1
    end_epoch = epochs + 1

    if state:
      model.load_state_dict(state['state_dict'])
      optimizer.load_state_dict(state['optimizer'])
      start_epoch = state['epoch']+1
      end_epoch = epochs + state['epoch']+1

    #Define loss function i.e nn.CTCLoss()
    criterion = nn.CTCLoss(blank=17).to(device)

    #Define scheduler
    scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr=hparams['learning_rate'], 
                                            steps_per_epoch=int(len(train_loader)),
                                            epochs=hparams['epochs'],
                                            anneal_strategy='linear')
    
    #Iterate through the epochs and train and test the model
    iter_meter = IterMeter()
    for epoch in range(start_epoch, end_epoch):
        #Train the model using train(.) function
        train(model, device, train_loader, criterion, optimizer, scheduler, epoch, iter_meter)

        #Evaluate the model using test(.) function
        test(model, device, test_loader, criterion, epoch, iter_meter)

    state = {
      'epoch': epoch,
      'state_dict': model.state_dict(),
      'optimizer': optimizer.state_dict(),
    }

    return state

# %%
###############################################################################
#Execute the main script
###############################################################################
learning_rate = 5e-4
batch_size = 10
epochs = 5
hparams = {
          "n_cnn_layers": 2,
          "n_rnn_layers": 1,
          "rnn_dim": 128,
          "n_class": 18,
          "n_feats": 64,
          "stride":2,
          "dropout": 0.1,
          "learning_rate": learning_rate,
          "batch_size": batch_size,
          "epochs": epochs
}

filepath = "/content/drive/MyDrive/state_0.pth"
prevState = torch.load(filepath)

state  = main(hparams, train_loader, test_loader, state=prevState)
torch.save(state, "/content/drive/MyDrive/state.pth")
# Out:
# SpeechRecognitionModel(
#   (cnn): Conv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (rescnn_layers): Sequential(
#     (0): ResidualCNN(
#       (cnn1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cnn2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (dropout2): Dropout(p=0.1, inplace=False)
#       (layer_norm1): CNNLayerNorm(
#         (layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       )
#       (layer_norm2): CNNLayerNorm(
#         (layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (1): ResidualCNN(
#       (cnn1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cnn2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (dropout2): Dropout(p=0.1, inplace=False)
#       (layer_norm1): CNNLayerNorm(
#         (layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       )
#       (layer_norm2): CNNLayerNorm(
#         (layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (fully_connected): Linear(in_features=1024, out_features=128, bias=True)
#   (birnn_layers): Sequential(
#     (0): BidirectionalGRU(
#       (BiGRU): GRU(128, 128, batch_first=True, bidirectional=True)
#       (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=128, bias=True)
#     (1): GELU(approximate=none)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=128, out_features=18, bias=True)
#   )
# )
# Num Model Parameters 402386
# Train Epoch: 11 [0/8613 (0%)]	Loss: 0.452330
# Train Epoch: 11 [1000/8613 (12%)]	Loss: 0.394087
# Train Epoch: 11 [2000/8613 (23%)]	Loss: 0.469855
# Train Epoch: 11 [3000/8613 (35%)]	Loss: 0.811487
# Train Epoch: 11 [4000/8613 (46%)]	Loss: 0.516886
# Train Epoch: 11 [5000/8613 (58%)]	Loss: 0.796661
# Train Epoch: 11 [6000/8613 (70%)]	Loss: 0.956945
# Train Epoch: 11 [7000/8613 (81%)]	Loss: 0.509599
# Train Epoch: 11 [8000/8613 (93%)]	Loss: 0.427942
#
# evaluating...
# Test set: Average loss: 0.0401, Average CER: 0.011097 Average WER: 0.0310
#
# Train Epoch: 12 [0/8613 (0%)]	Loss: 0.653052
# Train Epoch: 12 [1000/8613 (12%)]	Loss: 0.532368
# Train Epoch: 12 [2000/8613 (23%)]	Loss: 0.849607
# Train Epoch: 12 [3000/8613 (35%)]	Loss: 0.322998
# Train Epoch: 12 [4000/8613 (46%)]	Loss: 0.329008
# Train Epoch: 12 [5000/8613 (58%)]	Loss: 0.290944
# Train Epoch: 12 [6000/8613 (70%)]	Loss: 0.899750
# Train Epoch: 12 [7000/8613 (81%)]	Loss: 0.686722
# Train Epoch: 12 [8000/8613 (93%)]	Loss: 1.062685
#
# evaluating...
# Test set: Average loss: 0.0339, Average CER: 0.008670 Average WER: 0.0258
#
# Train Epoch: 13 [0/8613 (0%)]	Loss: 0.862071
# Train Epoch: 13 [1000/8613 (12%)]	Loss: 0.310412
# Train Epoch: 13 [2000/8613 (23%)]	Loss: 0.321723
# Train Epoch: 13 [3000/8613 (35%)]	Loss: 0.555580
# Train Epoch: 13 [4000/8613 (46%)]	Loss: 0.796341
# Train Epoch: 13 [5000/8613 (58%)]	Loss: 0.570528
# Train Epoch: 13 [6000/8613 (70%)]	Loss: 0.508612
# Train Epoch: 13 [7000/8613 (81%)]	Loss: 0.166504
# Train Epoch: 13 [8000/8613 (93%)]	Loss: 0.517616
#
# evaluating...
# Test set: Average loss: 0.0377, Average CER: 0.009646 Average WER: 0.0284
#
# Train Epoch: 14 [0/8613 (0%)]	Loss: 0.680857
# Train Epoch: 14 [1000/8613 (12%)]	Loss: 0.406233
# Train Epoch: 14 [2000/8613 (23%)]	Loss: 0.491899
# Train Epoch: 14 [3000/8613 (35%)]	Loss: 0.114975
# Train Epoch: 14 [4000/8613 (46%)]	Loss: 0.618293
# Train Epoch: 14 [5000/8613 (58%)]	Loss: 0.514385
# Train Epoch: 14 [6000/8613 (70%)]	Loss: 0.767237
# Train Epoch: 14 [7000/8613 (81%)]	Loss: 0.991386
# Train Epoch: 14 [8000/8613 (93%)]	Loss: 0.957651
#
# evaluating...
# Test set: Average loss: 0.0279, Average CER: 0.007940 Average WER: 0.0233
#
# Train Epoch: 15 [0/8613 (0%)]	Loss: 0.539615
# Train Epoch: 15 [1000/8613 (12%)]	Loss: 0.417511
# Train Epoch: 15 [2000/8613 (23%)]	Loss: 1.000018
# Train Epoch: 15 [3000/8613 (35%)]	Loss: 0.279366
# Train Epoch: 15 [4000/8613 (46%)]	Loss: 0.350521
# Train Epoch: 15 [5000/8613 (58%)]	Loss: 0.364327
# Train Epoch: 15 [6000/8613 (70%)]	Loss: 0.544270
# Train Epoch: 15 [7000/8613 (81%)]	Loss: 0.986860
# Train Epoch: 15 [8000/8613 (93%)]	Loss: 0.306713
#
# evaluating...
# Test set: Average loss: 0.0224, Average CER: 0.005820 Average WER: 0.0178

# %% [markdown]
# <h4> <b> Improvements : </b>
#
# <dd> <h4> - Experiment with the architecture and come up with the best architecture
#   </h4> </dd>
#
# <dd> <h4> - Use different decoders and report your observations  </h4> </dd>

# %% [markdown]
# ## Improvements & Different decoders in architecture

# %%
import torch
import torchaudio
import time
from typing import List
import IPython
import matplotlib.pyplot as plt
from torchaudio.models.decoder import ctc_decoder
from torchaudio.utils import download_asset

tokens = ["'", "<SPACE>", "e" ,"f" ,"g" ,"h" ,"i" ,"n" ,"o" ,"r" ,"s" ,"t" ,"u" ,"v" ,"w" ,"x" ,"z", "17", "|"]

################################################################################
#Beam Search Decoder
################################################################################

beam_search_decoder = ctc_decoder(
    lexicon=None,
    tokens=tokens,
    nbest=3,
    beam_size=1500,
    blank_token="17"
)

# %%
def test(hparams, state, device, test_loader, decoder="greedy"):

    model = SpeechRecognitionModel(
        hparams['n_cnn_layers'], hparams['n_rnn_layers'], hparams['rnn_dim'],
        hparams['n_class'], hparams['n_feats'], hparams['stride'], hparams['dropout']
        ).to(device)
    model.load_state_dict(state['state_dict'])

    print('\nevaluating...')
    model.eval()
    test_loss = 0
    test_cer, test_wer = [], []

    with torch.no_grad():
        for i, _data in enumerate(test_loader):
            #Load data and labels
            spectrograms, labels, input_lengths, label_lengths = _data 
            spectrograms, labels = spectrograms.to(device), labels.to(device)

            #Get the predictions
            output = model(spectrograms)  # (batch, time, n_class)
            output = F.log_softmax(output, dim=2)
            output = output.transpose(0, 1) # (time, batch, n_class)

            if decoder=="greedy":
              #Decode the text information using GreedyDecoder
              decoded_preds, decoded_targets = GreedyDecoder(output.transpose(0, 1), labels, label_lengths)

            elif decoder=="beam":
              decoded_preds = []
              decoded_targets = []

              for emission in output.transpose(0, 1):
                emission = emission[None,:]
                beam_search_result = beam_search_decoder(emission)
                def rem(x):
                  if x not in [17,18]:
                    return True
                  return False
                final_tokens = list(filter(rem, beam_search_result[0][0].tokens.tolist()))
                beam_search_transcript = text_transform.int_to_text(final_tokens)
                decoded_preds.append(beam_search_transcript)

              for i in range(len(labels)):
                decoded_targets.append(text_transform.int_to_text(labels[i][:label_lengths[i]].tolist()))
            
            #Compute CER and WER
            for j in range(len(decoded_preds)):
                test_cer.append(cer(decoded_targets[j], decoded_preds[j]))
                test_wer.append(wer(decoded_targets[j], decoded_preds[j]))

    #Compute average CER and WER
    avg_cer = sum(test_cer)/len(test_cer)
    avg_wer = sum(test_wer)/len(test_wer)

    print('Test set: Average CER: {:4f} Average WER: {:.4f}\n'.format(avg_cer, avg_wer))

# %%
hparams = {
          "n_cnn_layers": 2,
          "n_rnn_layers": 1,
          "rnn_dim": 128,
          "n_class": 18,
          "n_feats": 64,
          "stride":2,
          "dropout": 0.1
}

indexes = list(range(0, 1000, 1))
testset_1 = torch.utils.data.Subset(test_dataset, indexes)
decoder_test_loader = data.DataLoader(dataset=test_dataset,
                                batch_size=BATCH_SIZE,
                                shuffle=False,
                                collate_fn=lambda x: data_processing(x, 'valid'))

filepath = "/content/drive/MyDrive/state.pth"
state = torch.load(filepath)

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

test(hparams, state, device, decoder_test_loader, decoder="greedy")
# Out:
# evaluating...
# Test set: Average CER: 0.007433 Average WER: 0.0228

# %%
use_cuda = torch.cuda.is_available()
device = "cpu"

test(hparams, state, device, decoder_test_loader, decoder="beam")
# Out:
# evaluating...
# Test set: Average CER: 0.007433 Average WER: 0.0228

# %% [markdown]
# ## Understanding beam sizes and their impact

# %%
model = SpeechRecognitionModel(
        hparams['n_cnn_layers'], hparams['n_rnn_layers'], hparams['rnn_dim'],
        hparams['n_class'], hparams['n_feats'], hparams['stride'], hparams['dropout']
        ).to(device)
model.load_state_dict(state['state_dict'])
model.eval()

speech_file = "/content/1396z33a.wav"
IPython.display.Audio(speech_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
waveform, sample_rate = torchaudio.load(speech_file)
spec = valid_audio_transforms(waveform).squeeze(0)
output = model(spec[None, None, :])
output = F.log_softmax(output, dim=2)

beam_search_result = beam_search_decoder(output)

def rem(x):
    if x not in [17,18]:
        return True
    return False

final_tokens = list(filter(rem, beam_search_result[0][0].tokens.tolist()))
beam_search_transcript = text_transform.int_to_text(final_tokens)

if sample_rate != 16000:
    waveform = torchaudio.functional.resample(waveform, sample_rate, 16000)

actual_transcript = "one three nine six zero three three"

beam_search_wer = torchaudio.functional.edit_distance(actual_transcript, beam_search_transcript) / len(
    actual_transcript
)

print("Actual Transcript : ", actual_transcript)
print(f"WER: {beam_search_wer}")
# Out:
# Actual Transcript :  one three nine six zero three three
# WER: 0.02857142857142857

# %%
timesteps = beam_search_result[0][0].timesteps
predicted_tokens = beam_search_decoder.idxs_to_tokens(beam_search_result[0][0].tokens)

print(predicted_tokens, len(predicted_tokens))
print(timesteps, timesteps.shape[0])
# Out:
# ['|', 'o', 'n', 'e', '<SPACE>', 't', 'h', 'r', 'e', 'e', '<SPACE>', 'n', 'i', 'n', 'e', 's', 'i', 'x', '<SPACE>', 'z', 'e', 'r', 'o', '<SPACE>', 't', 'h', 'r', 'e', 'e', '<SPACE>', 't', 'h', 'r', 'e', 'e', '|'] 36
# tensor([  0,   1,   2,  16,  18,  21,  23,  25,  27,  30,  34,  36,  37,  39,
#          48,  56,  57,  80,  84,  86,  87,  97, 101, 108, 110, 111, 114, 115,
#         119, 121, 123, 124, 127, 129, 134, 155], dtype=torch.int32) 36

# %%
def print_decoded(decoder, emission, param, param_value):
    start_time = time.monotonic()

    result = decoder(emission)
    decode_time = time.monotonic() - start_time

    final_tokens = list(filter(rem, beam_search_result[0][0].tokens.tolist()))
    transcript = text_transform.int_to_text(final_tokens)

    score = result[0][0].score
    print(f"{param} {param_value:<3}: {transcript} (score: {score:.2f}; {decode_time:.4f} secs)")

# %%
for i in range(3):
    final_tokens = list(filter(rem, beam_search_result[0][i].tokens.tolist()))
    transcript = text_transform.int_to_text(final_tokens)
    score = beam_search_result[0][i].score
    print(f"{transcript} (score: {score})")
# Out:
# one three ninesix zero three three (score: -10.97612489641432)
# one three oinesix zero three three (score: -11.78038354099516)
# one three nineix zero three three (score: -11.96708570302252)

# %%
beam_sizes = [1, 5, 50, 500]

for beam_size in beam_sizes:
    beam_search_decoder = ctc_decoder(
        lexicon=None,
        tokens=tokens,
        nbest=3,
        beam_size=beam_size,
        blank_token="17"
    )

    print_decoded(beam_search_decoder, output, "beam size", beam_size)
# Out:
# beam size 1  : one three ninesix zero three three (score: -10.98; 0.0018 secs)
# beam size 5  : one three ninesix zero three three (score: -10.98; 0.0024 secs)
# beam size 50 : one three ninesix zero three three (score: -10.98; 0.0291 secs)
# beam size 500: one three ninesix zero three three (score: -10.98; 0.2853 secs)

# %%
num_tokens = len(tokens)
beam_size_tokens = [1, 5, 10, num_tokens]

for beam_size_token in beam_size_tokens:
    beam_search_decoder = ctc_decoder(
        lexicon=None,
        tokens=tokens,
        nbest=3,
        beam_size_token=beam_size_token,
        blank_token="17"
    )

    print_decoded(beam_search_decoder, output, "beam size token", beam_size_token)
# Out:
# beam size token 1  : one three ninesix zero three three (score: -10.98; 0.0015 secs)
# beam size token 5  : one three ninesix zero three three (score: -10.98; 0.0419 secs)
# beam size token 10 : one three ninesix zero three three (score: -10.98; 0.0107 secs)
# beam size token 19 : one three ninesix zero three three (score: -10.98; 0.0183 secs)

# %%
beam_thresholds = [1, 5, 10, 25]

for beam_threshold in beam_thresholds:
    beam_search_decoder = ctc_decoder(
        lexicon=None,
        tokens=tokens,
        nbest=3,
        beam_threshold=beam_threshold,
        blank_token="17"
    )

    print_decoded(beam_search_decoder, output, "beam threshold", beam_threshold)
# Out:
# beam threshold 1  : one three ninesix zero three three (score: -10.98; 0.0043 secs)
# beam threshold 5  : one three ninesix zero three three (score: -10.98; 0.0074 secs)
# beam threshold 10 : one three ninesix zero three three (score: -10.98; 0.0074 secs)
# beam threshold 25 : one three ninesix zero three three (score: -10.98; 0.0150 secs)

# %% [markdown]
# ## Report
#
# Above speech recognition model with 400K parameters gives 0.58% CER and 1.7% WER on test dataset. With TDIGITS dataset, we are getting same performance for both greedy and beam search decoding. As observed on TDIGITS, there is no much performance imporvement with bigger beam search sizes.
